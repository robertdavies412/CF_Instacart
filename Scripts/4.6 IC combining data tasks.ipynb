# %% [markdown]
# # Table of Contents
# ## 1. Importing libraries
# ## 2. Task responses

# %% [markdown]
# # 1. Importing libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Task responses

# %% [markdown]
# ## Q3. Importing data

# %%
# Import 'orders_products_combined' data

path = r'C:\Users\radav\OneDrive\Documents\Career Foundry\Data Analytics\Immersion\Achievement 4 Python Fundamentals\Instacart Basket Analysis'

# %%
df_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ## Q4. Check shape of imported dataframe

# %%
# Check shape of df_merged

df_merged.shape
# Out:
# (32434489, 11)

# %% [markdown]
# ## Q5. Combine dataframe with products data set

# %%
# Import cleaned products data set

df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
# Check the output of the two dataframes

df_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order customer_status  product_id  add_to_cart_order  \
# 0                     NaN             New         196                  1
# 1                     NaN             New       14084                  2
# 2                     NaN             New       12427                  3
# 3                     NaN             New       26088                  4
# 4                     NaN             New       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# ...

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Delete '_merge' column from merged dataframe

df_merged = df_merged.drop(columns = ['_merge'])

# %%
# Re-check output of merged dataframe

df_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order customer_status  product_id  add_to_cart_order  \
# 0                     NaN             New         196                  1
# 1                     NaN             New       14084                  2
# 2                     NaN             New       12427                  3
# 3                     NaN             New       26088                  4
# 4                     NaN             New       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# ...

# %%
# Delete unncessary columns in products dataframe

df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
# Re-check output of products dataframe

df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Merge datasets

df_merged_large = df_merged.merge(df_prods, on = 'product_id', indicator = True)

# %%
# Check the output

df_merged_large.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order customer_status  product_id  add_to_cart_order  \
# 0                     NaN             New         196                  1
# 1                    15.0        Existing         196                  1
# 2                    21.0        Existing         196                  1
# 3                    29.0        Existing         196                  1
# 4                    28.0        Existing         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge
# ...

# %% [markdown]
# ## Q6. Confirm merge results

# %%
# Confirm the results of the merge using the merge flag

df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged_large.shape
# Out:
# (32404859, 15)

# %% [markdown]
# ## Q7. Export merged dataframe

# %%
# Export merged dataframe in pickle format

df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
